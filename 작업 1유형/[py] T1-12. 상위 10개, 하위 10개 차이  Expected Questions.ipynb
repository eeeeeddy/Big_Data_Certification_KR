# %% [markdown]
# - 실수한 점
#   - 시간에 따라 접종률이 증가하는지 파악하지 못함

# %%
# 주어진 데이터에서 상위 10개 국가의 접종률 평균과 하위 10개 국가의 접종률 평균을 구하고, 그 차이를 구해보세요 
# (단, 100%가 넘는 접종률 제거, 소수 첫째자리까지 출력)

# - 데이터셋 : ../input/covid-vaccination-vs-death/covid-vaccination-vs-death_ratio.csv
# - 오른쪽 상단 copy&edit 클릭 -> 예상문제 풀이 시작
# - File -> Editor Type -> Script

import pandas as pd

df = pd.read_csv('/kaggle/input/covid-vaccination-vs-death/covid-vaccination-vs-death_ratio.csv')
df.head()
# Out:
#    Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0           0  Afghanistan      AFG  2021-05-11            504502.0
# 1           1  Afghanistan      AFG  2021-05-20            547901.0
# 2           2  Afghanistan      AFG  2021-05-24            573277.0
# 3           3  Afghanistan      AFG  2021-05-26            590454.0
# 4           4  Afghanistan      AFG  2021-05-27            593313.0
#
#    people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# 0           448878.0                  55624.0          12  40374668.0
# 1           470341.0                  77560.0          10  40374668.0
# 2           476367.0                  96910.0          10  40374668.0
# 3           479372.0                 111082.0          19  40374668.0
# 4           479574.0                 113739.0          14  40374668.0
#
#       ratio
# 0  1.111781
# 1  1.164941
# 2  1.179866
# 3  1.187309
# 4  1.187809

# %%
# 데이터가 date별 백신 접종 현황이기 때문에 국가별로 groupby
new_df = df.groupby('country').max()
new_df
# Out:
#                                                     Unnamed: 0 iso_code  \
# country
# Afghanistan                                                 35      AFG
# Albania                                                    219      ALB
# Algeria                                                    239      DZA
# Andorra                                                    270      AND
# Angola                                                     323      AGO
# ...                                                        ...      ...
# Wallis and Futuna                                        32473      WLF
# Yemen                                                    32488      YEM
# Zambia                                                   32559      ZMB
# Zimbabwe                                                 32910      ZWE
# occupied Palestinian territory, including east ...       23198      PSE
#
#                                                           date  \
# country
# ...

# %%
# ratio를 기준으로 내림차순으로 정렬
new_df = new_df.sort_values('ratio', ascending=False)
new_df
# Out:
#                       Unnamed: 0 iso_code        date  total_vaccinations  \
# country
# Gibraltar                  11368      GIB  2022-03-24            116358.0
# Malta                      19948      MLT  2022-03-28           1255851.0
# Niue                       22376      NIU  2022-03-13              4161.0
# United Arab Emirates       30916      ARE  2022-03-29          24463702.0
# Portugal                   24636      PRT  2022-03-10          22923599.0
# ...                          ...      ...         ...                 ...
# Papua New Guinea           23300      PNG  2022-03-28            574716.0
# Yemen                      32488      YEM  2022-03-16            807502.0
# Chad                        5884      TCD  2022-03-18            419469.0
# Haiti                      12640      HTI  2022-03-23            249801.0
# Burundi                     4798      BDI  2022-03-18             12166.0
#
# ...

# %%
# 접종률이 100이 넘는 데이터 제거 >> 접종률 100 이하인 데이터만 선택 후 상/하위 10개 국가 선택
new_df = new_df[new_df['ratio'] <= 100]
top10 = new_df.head(10)
bot10 = new_df.tail(10)

# %%
round(top10.ratio.mean() - bot10.ratio.mean(), 1)
# Out:
# 88.4
